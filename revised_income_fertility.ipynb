# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/aaron/Desktop/Code/State_of_the_State/Data/income_fertility.csv')

# %%
df.head()
# Out:
#            State  income_2010  income_2011  income_2012  income_2013  \
# 0       Maryland        68854        70004        71122        72483
# 1  Massachusetts        62072        62859        65339        66768
# 2     New Jersey        67681        67458        69667        70165
# 3  New Hampshire        61042        62647        63280        64230
# 4     California        57708        57287        58328        60190
#
#    income_2014  income_2015  income_2016  income_2017  income_2018  ...  \
# 0        73971        75847        78945        80776        83242  ...
# 1        69160        70628        75297        77385        79835  ...
# 2        71919        72222        76126        80088        81740  ...
# 3        66532        70303        70936        73381        74991  ...
# 4        61933        64500        67739        71805        75277  ...
#
#    FertilityRate_2012  FertilityRate_2013  FertilityRate_2014  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                50 non-null     object
#  1   income_2010          50 non-null     int64
#  2   income_2011          50 non-null     int64
#  3   income_2012          50 non-null     int64
#  4   income_2013          50 non-null     int64
#  5   income_2014          50 non-null     int64
#  6   income_2015          50 non-null     int64
#  7   income_2016          50 non-null     int64
#  8   income_2017          50 non-null     int64
#  9   income_2018          50 non-null     int64
#  10  income_2019          50 non-null     int64
#  11  income_2021          50 non-null     int64
#  12  FertilityRate_2010   50 non-null     float64
#  13  FertilityRate_2011   50 non-null     float64
#  14  FertilityRate_2012   50 non-null     float64
# ...

# %%
income_columns = [col for col in df.columns if 'income_' or 'State' in col]
income_df = df[income_columns]
income_df
# Out:
#              State  income_2010  income_2011  income_2012  income_2013  \
# 0         Maryland        68854        70004        71122        72483
# 1    Massachusetts        62072        62859        65339        66768
# 2       New Jersey        67681        67458        69667        70165
# 3    New Hampshire        61042        62647        63280        64230
# 4       California        57708        57287        58328        60190
# 5           Hawaii        63030        61821        66259        68020
# 6       Washington        55631        56835        57573        58405
# 7      Connecticut        64032        65753        67276        67098
# 8         Colorado        54046        55387        56765        58823
# 9         Virginia        60674        61882        61741        62666
# 10            Utah        54744        55869        57049        59770
# 11          Alaska        64576        67825        67712        72237
# ...

# %%
fertility_columns = [col for col in df.columns if 'FertilityRate' in col]
fertility_df = df[fertilityrate_columns]
fertility_df
# Out:
#              State  FertilityRate_2010  FertilityRate_2011  \
# 0         Maryland                1.89                1.85
# 1    Massachusetts                1.67                1.67
# 2       New Jersey                1.90                1.88
# 3    New Hampshire                1.67                1.67
# 4       California                1.95                1.90
# 5           Hawaii                2.15                2.11
# 6       Washington                1.91                1.89
# 7      Connecticut                1.72                1.71
# 8         Colorado                1.92                1.85
# 9         Virginia                1.88                1.85
# 10            Utah                2.45                2.38
# 11          Alaska                2.35                2.28
# 12       Minnesota                1.96                1.95
# 13        New York                1.81                1.79
# 14    Rhode Island                1.63                1.60
# ...

# %%
df[['income_2010', 'income_2021']].describe()
# Out:
#         income_2010   income_2021
# count     50.000000     50.000000
# mean   49755.060000  68826.880000
# std     8060.364147  11026.532015
# min    36851.000000  48716.000000
# 25%    43692.750000  62382.250000
# 50%    48332.500000  66539.000000
# 75%    54595.000000  76868.500000
# max    68854.000000  90203.000000

# %%
df[['FertilityRate_2010', 'FertilityRate_2021']].describe()
# Out:
#        FertilityRate_2010  FertilityRate_2021
# count           50.000000           50.000000
# mean             1.949600            1.694200
# std              0.171595            0.153105
# min              1.630000            1.370000
# 25%              1.872500            1.587500
# 50%              1.940000            1.700000
# 75%              2.032500            1.810000
# max              2.450000            2.070000

# %%
average_income_per_year = df[[col for col in df.columns if 'income_' in col]].mean()
average_income_per_year
# Out:
# income_2010    49755.06
# income_2011    50654.36
# income_2012    51682.70
# income_2013    52884.10
# income_2014    54109.72
# income_2015    56022.34
# income_2016    57795.84
# income_2017    59710.80
# income_2018    61549.28
# income_2019    64976.22
# income_2021    68826.88
# dtype: float64

# %%
average_fertility_per_year = df[[col for col in df.columns if 'FertilityRate' in col]].mean()
average_fertility_per_year
# Out:
# FertilityRate_2010     1.9496
# FertilityRate_2011     1.9164
# FertilityRate_2012     1.9030
# FertilityRate_2013     1.8848
# FertilityRate_2014     1.8886
# FertilityRate_2015     1.8740
# FertilityRate_2016     1.8472
# FertilityRate_2017     1.7958
# FertilityRate_2018     1.7580
# FertilityRate_2019     1.7334
# FertilityRate_2021     1.6942
# FertilityRateChange   -0.2554
# dtype: float64

# %%
income_columns = [col for col in df.columns if 'income_' in col]
melted_df = df.melt(id_vars='State', value_vars=income_columns, var_name='Year', value_name='Income')

# Convert 'Year' to a numerical value (e.g., 'income_2010' to 2010)
melted_df['Year'] = melted_df['Year'].str.replace('income_', '').astype(int)

# Step 2: Plot the Data
plt.figure(figsize=(10, 6))
for state in melted_df['State'].unique():
    state_data = melted_df[melted_df['State'] == state]
    plt.plot(state_data['Year'], state_data['Income'], label=state)

plt.xlabel('Year')
plt.ylabel('Income')
plt.title('Income over Years by State')
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Step 1: Reshape the DataFrame for Fertility Rates
fertility_columns = [col for col in df.columns if 'FertilityRate_' in col]
melted_df = df.melt(id_vars='State', value_vars=fertility_columns, var_name='Year', value_name='FertilityRate')

# Convert 'Year' to a numerical value (e.g., 'FertilityRate_2010' to 2010)
melted_df['Year'] = melted_df['Year'].str.replace('FertilityRate_', '').astype(int)

# Step 2: Plot the Data for Fertility Rates
plt.figure(figsize=(10, 6))
for state in melted_df['State'].unique():
    state_data = melted_df[melted_df['State'] == state]
    plt.plot(state_data['Year'], state_data['FertilityRate'], label=state)

plt.xlabel('Year')
plt.ylabel('Fertility Rate')
plt.title('Fertility Rate over Years by State')
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate change in fertility rate for each state
fertility_change = melted_df.groupby('State')['FertilityRate'].agg([np.min, np.max])
fertility_change['change'] = fertility_change['amax'] - fertility_change['amin']

# Identify states with the most and least change
most_change_states = fertility_change['change'].nlargest(2).index
least_change_states = fertility_change['change'].nsmallest(2).index

# Filter the melted_df for these states
filtered_states = most_change_states.union(least_change_states)
filtered_df = melted_df[melted_df['State'].isin(filtered_states)]

# Plot the data
plt.figure(figsize=(10, 6))
for state in filtered_df['State'].unique():
    state_data = filtered_df[filtered_df['State'] == state]
    plt.plot(state_data['Year'], state_data['FertilityRate'], label=state)

plt.xlabel('Year')
plt.ylabel('Fertility Rate')
plt.title('Fertility Rate Changes for States with Most and Least Change')
plt.legend(title='State')
plt.show()
